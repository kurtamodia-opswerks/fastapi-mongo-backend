# %%
import pandas as pd
import sys

def view_parquet_file(file_path):
    """
    Reads a parquet file and prints its content to the console.
    """
    try:
        print(f"--- Contents of {file_path} ---")
        df = pd.read_parquet(file_path)
        print(df)
        print("-" * (len(file_path) + 22))
    except Exception as e:
        print(f"Error reading {file_path}: {e}")

# %%
df = view_parquet_file("/Users/kurtmatthewamodia/Downloads/weekend_daily_busiest_hours_df.parquet")
df
# Out:
# --- Contents of /Users/kurtmatthewamodia/Downloads/weekend_daily_busiest_hours_df.parquet ---
#       created_at_year_ph created_at_month_ph  created_at_day_of_month_ph  \
# 0                   2024             January                           6
# 1                   2024             January                           6
# 2                   2024             January                           6
# 3                   2024             January                           6
# 4                   2024             January                           6
# ...                  ...                 ...                         ...
# 4555                2025             October                          26
# 4556                2025             October                          26
# 4557                2025             October                          26
# 4558                2025             October                          26
# 4559                2025             October                          26
# ...
